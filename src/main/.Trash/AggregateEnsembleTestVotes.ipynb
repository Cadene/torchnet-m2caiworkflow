# %%
import pandas as pd
import numpy as np
import re

experiments = [
    'inceptionv3_1/16_08_05_05:04:07',
    'resnet_1/16_09_06_11:31:46',
    'resnet_1/16_09_06_11:32:33',
    'inceptionv3_2/16_09_13_08:35:55',
    'inceptionv3_2/16_09_13_08:36:10',
    'inceptionv3_3/16_09_13_18:36:37',
    'inceptionv3_3/16_09_13_18:36:39',
    'inceptionv3_4/16_09_14_01:45:23',
    'inceptionv3_4/16_09_14_01:44:57',
    'inceptionv3_5/16_09_14_11:57:25',
    'inceptionv3_fold_0/16_09_15_09:53:05',
    'inceptionv3_fold_0/16_09_15_01:03:38',
    'inceptionv3_fold_1/16_09_15_01:04:10',
    'inceptionv3_fold_2/16_09_15_14:59:24',
    'inceptionv3_fold_2/16_09_15_14:58:53',
    'inceptionv3_fold_4/16_09_16_10:37:56',
    'inceptionv3_fold_4/16_09_16_10:38:19',
    'inceptionv3_fold_5/16_09_16_19:42:36',
    'inceptionv3_6b/16_09_14_16:21:56',
    'inceptionv3_6b/16_09_14_16:21:08',
    'inceptionv3_fold_6/16_09_16_19:34:42',
    'inceptionv3_fold_6/16_09_16_19:35:01'
]

def processEmissionTrain(l):
    data = l.strip().split(";")
    vote = [0,0,0,0,0,0,0,0]
    if len(data[1:]) == 8:
        ind = np.argmax(np.array(map(float, data[1:])))
        vote[ind] = 1
    return [data[0]] + vote

data = []

for exp in experiments:
    f = open('../extract/'+exp+'/testset.csv', "r")
    data += map(processEmissionTrain, f.readlines()[1:])

# %%
print data[0]
print data[10000]
print len(data)
# Out:
# ['/local/robert/m2cai/workflow/imagesTest/test_workflow_video_01-0008.jpg', 0, 0, 0, 0, 0, 0, 0, 1]
# ['/local/robert/m2cai/workflow/imagesTest/test_workflow_video_07-0724.jpg', 0, 0, 1, 0, 0, 0, 0, 0]
# 632104

# %%
dataDf = pd.DataFrame(data, columns=["file", "p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8"])

# %%
dataDf
# Out:
#                                                      file  p1  p2  p3  p4  p5  \
# 0       /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   0
# 1       /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 2       /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   1   0   0
# 3       /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 4       /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 5       /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 6       /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 7       /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   0
# 8       /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   0
# 9       /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   0
# 10      /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   0
# 11      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 12      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 13      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 14      /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   1
# 15      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 16      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 17      /local/robert/m2cai/workflow/imagesTest/test_w...   0   0   0   0   1
# 18      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 19      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 20      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 21      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 22      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 23      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 24      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 25      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 26      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 27      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 28      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 29      /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# ...                                                   ...  ..  ..  ..  ..  ..
# 632074  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632075  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632076  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632077  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632078  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632079  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632080  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632081  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632082  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632083  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632084  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632085  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632086  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632087  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632088  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632089  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632090  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632091  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632092  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632093  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632094  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632095  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632096  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632097  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632098  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632099  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632100  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632101  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632102  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
# 632103  /local/robert/m2cai/workflow/imagesTest/test_w...   1   0   0   0   0
#
#         p6  p7  p8
# 0        0   0   1
# 1        0   0   0
# 2        0   0   0
# 3        0   0   0
# 4        0   0   0
# 5        0   0   0
# 6        0   0   0
# 7        0   0   1
# 8        0   1   0
# 9        0   0   1
# 10       0   0   1
# 11       0   0   0
# 12       0   0   0
# 13       0   0   0
# 14       0   0   0
# 15       0   0   0
# 16       0   0   0
# 17       0   0   0
# 18       0   0   0
# 19       0   0   0
# 20       0   0   0
# 21       0   0   0
# 22       0   0   0
# 23       0   0   0
# 24       0   0   0
# 25       0   0   0
# 26       0   0   0
# 27       0   0   0
# 28       0   0   0
# 29       0   0   0
# ...     ..  ..  ..
# 632074   0   0   0
# 632075   0   0   0
# 632076   0   0   0
# 632077   0   0   0
# 632078   0   0   0
# 632079   0   0   0
# 632080   0   0   0
# 632081   0   0   0
# 632082   0   0   0
# 632083   0   0   0
# 632084   0   0   0
# 632085   0   0   0
# 632086   0   0   0
# 632087   0   0   0
# 632088   0   0   0
# 632089   0   0   0
# 632090   0   0   0
# 632091   0   0   0
# 632092   0   0   0
# 632093   0   0   0
# 632094   0   0   0
# 632095   0   0   0
# 632096   0   0   0
# 632097   0   0   0
# 632098   0   0   0
# 632099   0   0   0
# 632100   0   0   0
# 632101   0   0   0
# 632102   0   0   0
# 632103   0   0   0
#
# [632104 rows x 9 columns]

# %%
groups = dataDf.groupby("file")

# %%
groupsAggr = groups.agg({"p1": "mean", "p2": "mean", "p3": "mean", "p4": "mean",
            "p5": "mean", "p6": "mean", "p7": "mean", "p8": "mean"})

# %%
groupsAggr.to_csv('../cnnPreds/test_ensemble_CV_votes.csv', index=True, sep=";")
